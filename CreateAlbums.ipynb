# %% [markdown]
# ### Create Albums

# %%
from sturdy_barnacle.db_utils import DatabaseManager
from sturdy_barnacle.image_album_manager import ImageAlbumManager
from sturdy_barnacle.image_visualizer import ImageVisualizer

# %%
db = DatabaseManager()
album_manager = ImageAlbumManager(db)
visualizer = ImageVisualizer(db)

album_manager.group_images_into_albums()
# Out:
# Tables cleared. Ready for a new clustering experiment.
# /Users/mamduhzabidi/Documents/GitHub/sturdy-barnacle/myenv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/mamduhzabidi/Documents/GitHub/sturdy-barnacle/myenv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Albums created successfully using t-SNE + HDBSCAN!
#     album_id album_name  num_images
# 13        14   Album 14         150
# 22        23   Album 23         142
# 60        61   Album 61         119
# 2          3    Album 3         103
# 15        16   Album 16          83
# ..       ...        ...         ...
# 48        49   Album 49          11
# 47        48   Album 48          11
# 16        17   Album 17          11
# 7          8    Album 8          10
# 25        26   Album 26          10
#
# [78 rows x 3 columns]

# %%
results = db.get_album_images(album_id=17)
for image in results:
    visualizer.visualize_image_metadata(image)
# Out:
# Image Path: /Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/0/07DEE421-BE1B-46A7-8E94-736542FCE6B9.jpeg
# Detected Objects: {}
# Caption: view from the top of the tower in seville
#
# Date Taken: 2017:06:12 15:24:12
# --------------------------------------------------
# Image Path: /Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/0/0185F51D-4533-43A5-BAA6-E98D7F3A00A7.jpeg
# Detected Objects: {}
# Caption: a view of a city from a high place
#
# Date Taken: 2017:06:08 19:18:19
# --------------------------------------------------
# Image Path: /Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/0/0A68D248-5034-43A6-8C38-5434B9DFD4D4.jpeg
# Detected Objects: {'person': 1}
# Caption: a view of the city from the top of a tower
#
# Date Taken: 2017:06:12 15:24:08
# --------------------------------------------------
# Image Path: /Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/1/1ADAEECF-0C4D-4A18-B3BC-CD4EA6D7E0C2.jpeg
# Detected Objects: {}
# Caption: the sky is blue
#
# Date Taken: 2017:06:12 15:24:46
# --------------------------------------------------
# Image Path: /Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/1/1934183C-FF2B-42FB-AAE3-1F74D2E1519F.jpeg
# Detected Objects: {}
# Caption: a large city with many buildings
#
# Date Taken: 2017:06:08 19:18:31
# --------------------------------------------------
# Image Path: /Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/0/08824DF1-7017-4882-8450-86673107D384.jpeg
# Detected Objects: {}
# Caption: a view of the city from the top of a tower
#
# Date Taken: 2017:06:12 15:24:07
# --------------------------------------------------
# Image Path: /Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/1/12487898-882B-4C93-A31B-24A029EDA65F.jpeg
# Detected Objects: {'umbrella': 1, 'car': 1}
# Caption: a view of a city from a high place
#
# Date Taken: 2017:06:08 18:24:38
# --------------------------------------------------
# Image Path: /Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/2/2AFE741D-185A-48F9-8D2E-235F8C3393F7.jpeg
# Detected Objects: {'person': 1}
# Caption: a large city with many buildings
#
# Date Taken: 2017:06:12 15:26:08
# --------------------------------------------------
# Image Path: /Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/2/20D7DA0A-4BF1-4217-A9E2-E55120557732.jpeg
# Detected Objects: {}
# Caption: a cloudy sky
#
# Date Taken: 2017:06:08 18:21:31
# --------------------------------------------------
# Image Path: /Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/2/20FA3E7B-6448-4D3B-9702-3B267F09FE63.jpeg
# Detected Objects: {}
# Caption: a view of a city from a high place
#
# Date Taken: 2017:06:08 18:24:39
# --------------------------------------------------
# Image Path: /Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/2/2467ABD0-F35F-4508-AF5E-522548BDD447.jpeg
# Detected Objects: {'person': 1}
# Caption: a view of the city from the top of a tower
#
# Date Taken: 2017:06:12 15:27:14
# --------------------------------------------------
