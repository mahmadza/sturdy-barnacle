# %% [markdown]
# ### Create Albums

# %%
from sturdy_barnacle.db_utils import DatabaseManager
from sturdy_barnacle.image_album_manager import ImageAlbumManager
from sturdy_barnacle.image_visualizer import ImageVisualizer

# %%
db = DatabaseManager()
album_manager = ImageAlbumManager(db)
visualizer = ImageVisualizer(db)

df_albums = album_manager.group_images_into_albums()

df_albums
# Out:
# Tables cleared successfully! Ready for a new clustering experiment.
# /Users/mamduhzabidi/Documents/GitHub/sturdy-barnacle/myenv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/mamduhzabidi/Documents/GitHub/sturdy-barnacle/myenv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# ✅ Albums created successfully using t-SNE + HDBSCAN!
#     album_id album_name  num_images
# 1          2    Album 2         216
# 24        25   Album 25         125
# 42        43   Album 43          75
# 44        45   Album 45          73
# 17        18   Album 18          72
# 16        17   Album 17          55
# 23        24   Album 24          51
# 29        30   Album 30          51
# 40        41   Album 41          50
# 14        15   Album 15          43
# 5          6    Album 6          41
# 20        21   Album 21          39
# 12        13   Album 13          37
# 10        11   Album 11          34
# 22        23   Album 23          33
# 38        39   Album 39          31
# 41        42   Album 42          30
# 18        19   Album 19          29
# 6          7    Album 7          26
# 43        44   Album 44          26
# 32        33   Album 33          23
# 25        26   Album 26          22
# 39        40   Album 40          21
# 19        20   Album 20          21
# 37        38   Album 38          21
# 11        12   Album 12          20
# 21        22   Album 22          19
# 8          9    Album 9          18
# 7          8    Album 8          18
# 33        34   Album 34          18
# 15        16   Album 16          16
# 27        28   Album 28          16
# 31        32   Album 32          16
# 36        37   Album 37          16
# 34        35   Album 35          15
# 26        27   Album 27          14
# 13        14   Album 14          14
# 45        46   Album 46          14
# 0          1    Album 1          13
# 2          3    Album 3          13
# 30        31   Album 31          12
# 28        29   Album 29          12
# 9         10   Album 10          12
# 35        36   Album 36          10
# 4          5    Album 5          10
# 3          4    Album 4          10
# 46        47   Album 47          10

# %%
results = db.get_images_by_album(album_id=4)
for image in results:
    visualizer.visualize_image_metadata(image)
# Out:
# Image Path: /Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/0/0658B012-6211-4E9F-9899-F3E132FE7E1F.jpeg
# Detected Objects: {}
# Caption: a large crater with a black smoke coming out of it
#
# Date Taken: 2017:07:06 14:22:35
# --------------------------------------------------
# Image Path: /Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/0/0CD6C225-8057-4C31-B68A-53393A777377.jpeg
# Detected Objects: {}
# Caption: the view from the top of the volcano
#
# Date Taken: 2017:07:06 14:32:05
# --------------------------------------------------
# Image Path: /Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/0/0850D226-2110-4D8C-BCB7-4E0E053443EC.jpeg
# Detected Objects: {}
# Caption: a plane flying over a mountain with a waterfall
#
# Date Taken: 2015:04:05 13:57:24
# --------------------------------------------------
# Image Path: /Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/0/0BABB184-3954-452A-A95F-7CB720D8904E.jpeg
# Detected Objects: {'car': 1, 'person': 2}
# Caption: a grassy hillside
#
# Date Taken: 2017:01:01 15:52:33
# --------------------------------------------------
# Image Path: /Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/0/04A5197F-2B34-4F4D-8BAA-0A9195E7AFE3.jpeg
# Detected Objects: {'person': 3}
# Caption: a view of a cliff with a river running through it
#
# Date Taken: 2017:01:01 14:12:53
# --------------------------------------------------
# Image Path: /Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/1/10E41FDD-55D6-4C1F-A473-2C77C7919C96.jpeg
# Detected Objects: {'person': 2, 'bicycle': 1}
# Caption: a grassy hillside
#
# Date Taken: 2017:01:01 15:52:40
# --------------------------------------------------
# Image Path: /Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/1/170B022F-4171-4811-AFDB-28E09F2263A2.jpeg
# Detected Objects: {}
# Caption: a large crater with a large hole in the ground
#
# Date Taken: 2017:07:06 14:33:49
# --------------------------------------------------
# Image Path: /Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/1/154CBD3E-619C-4D28-811D-A2185B8E1D2E.jpeg
# Detected Objects: {}
# Caption: a large waterfall in the middle of a forest
#
# Date Taken: 2017:01:01 15:24:03
# --------------------------------------------------
# Image Path: /Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/1/19873742-23D1-4EB2-82CF-35DF4FD13412.jpeg
# Detected Objects: {}
# Caption: a large mountain with a small rock on top
#
# Date Taken: 2017:07:06 14:30:18
# --------------------------------------------------
# Image Path: /Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/1/1974B7F9-5017-4B8E-8B5D-210FC377BEAD.jpeg
# Detected Objects: {}
# Caption: a large rock wall
#
# Date Taken: 2017:07:06 14:39:57
# --------------------------------------------------
