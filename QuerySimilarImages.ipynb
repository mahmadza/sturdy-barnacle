# %% [markdown]
# ### Query Similar Images

# %%
from sturdy_barnacle.db_utils import DatabaseManager
from sturdy_barnacle.image_processor import ImageProcessor
from sturdy_barnacle.image_visualizer import ImageVisualizer

# %%
db = DatabaseManager()
visualizer = ImageVisualizer(db)

# %%
image_path = "/Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/0/0C68C956-F136-434A-B7B1-24616E428169.jpeg"
processor = ImageProcessor(image_path, db)
# Out:
# 🚀 Initializing shared resources...
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# All models loaded successfully!

# %%
embedding = processor.compute_embedding()
results = db.find_similar_images(image_embedding=embedding, top_n=5)

# %%
for image in results:
    print(image)
    visualizer.visualize_image_metadata(image['image_path'])
# Out:
# {'image_path': '/Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/0/0C68C956-F136-434A-B7B1-24616E428169.jpeg', 'similarity': 1.0}
# Image Path: /Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/0/0C68C956-F136-434A-B7B1-24616E428169.jpeg
# Detected Objects: {}
# Caption: a painting of a cat and birds
#
# Date Taken: 2017:07:08 12:00:11
# --------------------------------------------------
# {'image_path': '/Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/1/1120E9E8-6C7D-4825-B282-639D5A7453C7.jpeg', 'similarity': 0.8873814613476374}
# Image Path: /Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/1/1120E9E8-6C7D-4825-B282-639D5A7453C7.jpeg
# Detected Objects: {'bird': 1, 'horse': 1}
# Caption: a painting of animals on a wall
#
# Date Taken: 2017:07:08 11:58:09
# --------------------------------------------------
# ...
