# %% [markdown]
# ### Create Albums
# Create albums using tSNE and HDBSCAN.

# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))

sys.path.insert(0, project_root)

# %%
from sturdy_barnacle.db_utils import DatabaseManager
from sturdy_barnacle.image_album_manager import ImageAlbumManager
from sturdy_barnacle.image_visualizer import ImageVisualizer
# Out:
# All table names are validated and safe.

# %%
db = DatabaseManager()
album_manager = ImageAlbumManager(db)
visualizer = ImageVisualizer(db)

album_df = album_manager.group_images_into_albums()

album_df.tail()
# Out:
# Tables cleared. Ready for a new clustering experiment.
# /Users/mamduhzabidi/Documents/GitHub/sturdy-barnacle/myenv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/mamduhzabidi/Documents/GitHub/sturdy-barnacle/myenv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Albums created successfully using t-SNE + HDBSCAN!
#      album_id album_name  num_images
# 73         74   Album 74          10
# 84         85   Album 85          10
# 89         90   Album 90          10
# 102       103  Album 103          10
# 66         67   Album 67          10

# %%
# View album images
results = db.get_album_images(album_id=67)
for image in results:
    visualizer.visualize_image_metadata(image)
# Out:
# Image Path: /Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/0/0DB7E3A8-3E1C-4B85-8A61-2406ACD97CA2.jpeg
# Detected Objects: {'bench': 1}
# Caption: a large room with a lot of columns and a lot of tiled floors
#
# Date Taken: 2017:06:15 13:58:12
# --------------------------------------------------
# Image Path: /Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/3/32D535EB-32D4-450D-81C2-1AE9FD5188E9.jpeg
# Detected Objects: {}
# Caption: the building is made of brick
#
# Date Taken: 2017:06:16 17:45:14
# --------------------------------------------------
# Image Path: /Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/3/3C71F457-8FEB-48C0-947C-6C4154ACD448.jpeg
# Detected Objects: {'bench': 1, 'chair': 1}
# Caption: the floor is made of brick
#
# Date Taken: 2017:06:15 13:58:14
# --------------------------------------------------
# Image Path: /Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/3/31D3ED9E-C83A-44F0-8F3C-C83CAAA5CB48.jpeg
# Detected Objects: {'person': 19}
# Caption: the interior of the alhambra palace
#
# Date Taken: 2017:06:15 13:47:45
# --------------------------------------------------
# Image Path: /Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/3/3C33AA81-3757-4286-A68F-F013CC0A13DD.jpeg
# Detected Objects: {}
# Caption: a building with a clock
#
# Date Taken: 2009:06:17 11:02:05
# --------------------------------------------------
# Image Path: /Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/0/0DC13ABF-B8E4-41F9-AF15-F1DF792B08AE.jpeg
# Detected Objects: {'bench': 1}
# Caption: a large room with a lot of columns and a lot of tiled floors
#
# Date Taken: 2017:06:15 13:58:13
# --------------------------------------------------
# Image Path: /Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/0/0D2A93A0-9B95-46EE-8451-A3906E0FCA8C.jpeg
# Detected Objects: {'chair': 1}
# Caption: a large room with a lot of columns and a floor
#
# Date Taken: 2017:06:15 13:57:52
# --------------------------------------------------
# Image Path: /Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/0/0E1D4E33-C270-424F-A3DF-278CC217E147.jpeg
# Detected Objects: {}
# Caption: the columns are painted
#
# Date Taken: 2017:07:08 11:25:30
# --------------------------------------------------
# Image Path: /Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/0/025CE633-00E7-4178-A3FE-7DA4B4E99C40.jpeg
# Detected Objects: {'bench': 1}
# Caption: the interior of a building with tiled walls and columns
#
# Date Taken: 2017:06:15 13:52:42
# --------------------------------------------------
# Image Path: /Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/2/2010806F-DDC5-4BDB-8C49-28C810037C47.jpeg
# Detected Objects: {'person': 17, 'handbag': 1}
# Caption: the interior of the alhambra palace
#
# Date Taken: 2017:06:15 13:47:44
# --------------------------------------------------
