# %% [markdown]
# ### Create Albums
# Create albums using tSNE and HDBSCAN.

# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))

sys.path.insert(0, project_root)

# %%
from sturdy_barnacle.db_utils import DatabaseManager
from sturdy_barnacle.image_album_manager import ImageAlbumManager
from sturdy_barnacle.image_visualizer import ImageVisualizer
# Out:
# All table names are validated and safe.

# %%
db = DatabaseManager()
album_manager = ImageAlbumManager(db)
visualizer = ImageVisualizer(db)

album_df = album_manager.group_images_into_albums()

album_df.tail()
# Out:
# Tables cleared. Ready for a new clustering experiment.
# /Users/mamduhzabidi/Documents/GitHub/sturdy-barnacle/myenv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/mamduhzabidi/Documents/GitHub/sturdy-barnacle/myenv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Albums created successfully using t-SNE + HDBSCAN!
#     album_id album_name  num_images
# 17        18   Album 18          10
# 37        38   Album 38          10
# 27        28   Album 28          10
# 24        25   Album 25          10
# 0          1    Album 1          10

# %%
# View album images
results = db.get_album_images(album_id=18)
for image in results:
    visualizer.visualize_image_metadata(image)
# Out:
# Image Path: /Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/3/3461EA11-5B5E-4FF7-9CFD-DBBB430C6BDD.jpeg
# Detected Objects: {'person': 1, 'boat': 1}
# Caption: a view of the lake from a pier under a cloudy sky
#
# Date Taken: 2013:12:25 11:15:24
# --------------------------------------------------
# Image Path: /Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/3/33A83BF1-0A27-4A02-9ACD-852E02CFF3F4.jpeg
# Detected Objects: {}
# Caption: the sky is dark
#
# Date Taken: 2017:07:02 19:01:35
# --------------------------------------------------
# Image Path: /Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/3/3F139B13-78F5-4BEF-BF6B-28518E7C27F0.jpeg
# Detected Objects: {'bird': 1}
# Caption: a boat is in the water
#
# Date Taken: 2013:12:25 11:27:16
# --------------------------------------------------
# Image Path: /Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/2/230946B2-263A-4EAC-937B-464B568FAE8E.jpeg
# Detected Objects: {'bird': 4, 'boat': 1}
# Caption: a view of the lake from the shore
#
# Date Taken: 2013:12:25 11:14:47
# --------------------------------------------------
# Image Path: /Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/2/2818491B-5114-4E76-AD4B-F74339327722.jpeg
# Detected Objects: {}
# Caption: the sky is dark
#
# Date Taken: 2017:07:02 19:01:35
# --------------------------------------------------
# Image Path: /Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/2/2E069C50-7160-4FE1-A059-69DEB2A00C3F.jpeg
# Detected Objects: {'boat': 4, 'bird': 2}
# Caption: a black and white photo of a lake and buildings
#
# Date Taken: 2013:12:25 11:11:22
# --------------------------------------------------
# Image Path: /Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/0/078068EF-C317-47B3-8E86-B6F0214A46EC.jpeg
# Detected Objects: {'bird': 1, 'boat': 3}
# Caption: a body of water
#
# Date Taken: 2013:12:25 11:17:23
# --------------------------------------------------
# Image Path: /Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/0/05D792EB-E67B-4A79-AED9-0D58C7A8EB3F.jpeg
# Detected Objects: {'bird': 1}
# Caption: a body of water
#
# Date Taken: 2013:12:25 11:14:16
# --------------------------------------------------
# Image Path: /Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/1/1A3B9808-55A8-4026-AAAD-20CCCF1A3B76.jpeg
# Detected Objects: {}
# Caption: a body of water
#
# Date Taken: 2017:07:02 19:02:06
# --------------------------------------------------
# Image Path: /Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/2/2E6711DC-628B-4543-A23B-FFB28ABC621B.jpeg
# Detected Objects: {'bird': 5}
# Caption: black and white photo of a lake and clouds
#
# Date Taken: 2013:12:25 11:11:36
# --------------------------------------------------
