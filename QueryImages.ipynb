# %% [markdown]
# ### Query Images

# %%
import os

from sturdy_barnacle.db_utils import DatabaseManager
from sturdy_barnacle.image_visualizer import ImageVisualizer

# %%
db = DatabaseManager()
visualizer = ImageVisualizer(db)

# %%
query_results = db.query_images_by_keyword("flower")

# %%
for i in range(len(query_results))[:5]:
    image_path = query_results[i].image_path
    visualizer.visualize_image_metadata(image_path)
# Out:
# Image Path: /Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/1/13516FBE-0B56-47D1-A0FB-D509D3C475BD.jpeg
# Detected Objects: {}
# Caption: a tree with white flowers and green leaves
#
# Date Taken: 2017:07:21 19:26:52
# --------------------------------------------------
# Image Path: /Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/0/02842C50-5BE6-42DF-9E28-F5630910865C.jpeg
# Detected Objects: {'potted plant': 1, 'bird': 1}
# Caption: a plant with flowers and leaves
#
# Date Taken: 2012:07:09 05:46:55
# --------------------------------------------------
# Image Path: /Users/mamduhzabidi/Pictures/Photos Library.photoslibrary/originals/0/00A9D143-7AEC-4BAC-AEDE-2F7BBBEC2C0C.jpeg
# Detected Objects: {}
# Caption: lavender flowers growing on the sidewalk near a wall
#
# Date Taken: 2015:07:26 17:21:25
# --------------------------------------------------
# ...
