# %% [markdown]
# ### Create Album Summary

# %%
from sturdy_barnacle.db_utils import DatabaseManager
from sturdy_barnacle.auto_album_manager import AutoAlbumManager
from sqlalchemy import text

def test_auto_album_summary():

    db = DatabaseManager()
    album_manager = AutoAlbumManager(db)
    
    # Fetch all album IDs
    session = db._get_session()
    album_ids = session.execute(text("SELECT id FROM image_albums")).fetchall()
    session.close()
    
    if not album_ids:
        print("No albums found in the database.")
        return
    
    for album_id in album_ids:
        album_id = album_id[0]
        detected_objects, descriptions, exif_locations = album_manager.get_cluster_metadata(album_id)
        summary = f"This album contains images with objects such as {', '.join(list(detected_objects.keys())[:5])}. "
        
        print(f"Album ID: {album_id}")
        print(f"Generated Summary: {summary}\n")

# %%
test_auto_album_summary()
# Out:
# Album ID: 1
# Generated Summary: This album contains images with objects such as person, cell phone, pizza, hot dog, bowl.
#
# Album ID: 2
# Generated Summary: This album contains images with objects such as boat, bird, chair, person, suitcase.
#
# Album ID: 3
# Generated Summary: This album contains images with objects such as tv, bowl, book, person, refrigerator.
#
# Album ID: 4
# Generated Summary: This album contains images with objects such as person, potted plant, cow, apple, handbag.
#
# Album ID: 5
# Generated Summary: This album contains images with objects such as person, bench, boat.
#
# Album ID: 6
# Generated Summary: This album contains images with objects such as sheep, bear, cow, suitcase, giraffe.
#
# Album ID: 7
# Generated Summary: This album contains images with objects such as person, chair, car, book, tv.
#
# Album ID: 8
# Generated Summary: This album contains images with objects such as person, backpack, umbrella, cup, frisbee.
#
# Album ID: 9
# Generated Summary: This album contains images with objects such as person, cup, chair, toilet, handbag.
#
# Album ID: 10
# Generated Summary: This album contains images with objects such as potted plant, apple, bird, handbag.
#
# Album ID: 11
# Generated Summary: This album contains images with objects such as person, bird, handbag, baseball glove, potted plant.
#
# Album ID: 12
# Generated Summary: This album contains images with objects such as potted plant, person, bench, backpack, bird.
#
# Album ID: 13
# Generated Summary: This album contains images with objects such as boat, car, person.
#
# Album ID: 14
# Generated Summary: This album contains images with objects such as person, handbag, backpack, potted plant, horse.
#
# Album ID: 15
# Generated Summary: This album contains images with objects such as boat, train, person, umbrella, kite.
#
# Album ID: 16
# Generated Summary: This album contains images with objects such as person, traffic light, backpack, car, boat.
#
# Album ID: 17
# Generated Summary: This album contains images with objects such as person, umbrella, car.
#
# Album ID: 18
# Generated Summary: This album contains images with objects such as bird, bench, person, car, traffic light.
#
# Album ID: 19
# Generated Summary: This album contains images with objects such as clock, cake, book, train, person.
#
# Album ID: 20
# Generated Summary: This album contains images with objects such as person, umbrella, chair, car, dining table.
#
# Album ID: 21
# Generated Summary: This album contains images with objects such as vase, bowl, cup, book, remote.
#
# Album ID: 22
# Generated Summary: This album contains images with objects such as person, backpack, car, bowl, handbag.
#
# Album ID: 23
# Generated Summary: This album contains images with objects such as person, tv, dining table, cake, knife.
#
# Album ID: 24
# Generated Summary: This album contains images with objects such as person, backpack, handbag, bottle, bird.
#
# Album ID: 25
# Generated Summary: This album contains images with objects such as person, backpack, bottle, handbag, skateboard.
#
# Album ID: 26
# Generated Summary: This album contains images with objects such as sheep, person, bench.
#
# Album ID: 27
# Generated Summary: This album contains images with objects such as .
#
# Album ID: 28
# Generated Summary: This album contains images with objects such as broccoli, apple, person, orange, backpack.
#
# Album ID: 29
# Generated Summary: This album contains images with objects such as orange, apple, broccoli, potted plant, teddy bear.
#
# Album ID: 30
# Generated Summary: This album contains images with objects such as person, cat, bed, toilet, cake.
#
# Album ID: 31
# Generated Summary: This album contains images with objects such as dog, chair, horse, person, teddy bear.
#
# Album ID: 32
# Generated Summary: This album contains images with objects such as bench, car, person, horse, bird.
#
# Album ID: 33
# Generated Summary: This album contains images with objects such as person, car, bird, traffic light, kite.
#
# Album ID: 34
# Generated Summary: This album contains images with objects such as bird, person, backpack, surfboard, bottle.
#
# Album ID: 35
# Generated Summary: This album contains images with objects such as car, bench, person.
#
# Album ID: 36
# Generated Summary: This album contains images with objects such as potted plant, bird, chair, apple, vase.
#
# Album ID: 37
# Generated Summary: This album contains images with objects such as bird, bench, person, donut, dining table.
#
# Album ID: 38
# Generated Summary: This album contains images with objects such as carrot, cake, sandwich, broccoli, apple.
#
# Album ID: 39
# Generated Summary: This album contains images with objects such as person, chair, motorcycle, potted plant, tv.
#
# Album ID: 40
# Generated Summary: This album contains images with objects such as person, car, potted plant, bicycle, handbag.
#
# Album ID: 41
# Generated Summary: This album contains images with objects such as person, bench, handbag, dog, bicycle.
#
# Album ID: 42
# Generated Summary: This album contains images with objects such as person, clock, wine glass, bird, chair.
#
# Album ID: 43
# Generated Summary: This album contains images with objects such as boat, person, bench, bus, train.
#
# Album ID: 44
# Generated Summary: This album contains images with objects such as car, truck, person, boat, potted plant.
#
# Album ID: 45
# Generated Summary: This album contains images with objects such as person, bench, car, suitcase, clock.
#
# Album ID: 46
# Generated Summary: This album contains images with objects such as car, person, motorcycle, tv, potted plant.
#
# Album ID: 47
# Generated Summary: This album contains images with objects such as car, traffic light, person, bicycle, clock.
#
# Album ID: 48
# Generated Summary: This album contains images with objects such as person, handbag, traffic light, umbrella, bench.
#
# Album ID: 49
# Generated Summary: This album contains images with objects such as car, clock, boat.
#
# Album ID: 50
# Generated Summary: This album contains images with objects such as boat, person, car, traffic light, umbrella.
#
# Album ID: 51
# Generated Summary: This album contains images with objects such as person, car, truck, bench, bird.
#
# Album ID: 52
# Generated Summary: This album contains images with objects such as umbrella, person, bird, kite, bus.
#
# Album ID: 53
# Generated Summary: This album contains images with objects such as person, chair, bench, umbrella, backpack.
#
# Album ID: 54
# Generated Summary: This album contains images with objects such as person, bus, airplane, suitcase, truck.
#
# Album ID: 55
# Generated Summary: This album contains images with objects such as person, car, horse, handbag, surfboard.
#
# Album ID: 56
# Generated Summary: This album contains images with objects such as boat, car, person, bird, bench.
#
# Album ID: 57
# Generated Summary: This album contains images with objects such as person, umbrella, bird, handbag, car.
#
# Album ID: 58
# Generated Summary: This album contains images with objects such as person, boat, umbrella, bench, clock.
#
# Album ID: 59
# Generated Summary: This album contains images with objects such as person, handbag, vase, backpack, bench.
#
# Album ID: 60
# Generated Summary: This album contains images with objects such as person, backpack, bottle, handbag, bench.
#
# Album ID: 61
# Generated Summary: This album contains images with objects such as bed, car, bench, clock, person.
#
# Album ID: 62
# Generated Summary: This album contains images with objects such as person, remote, cake, horse.
#
# Album ID: 63
# Generated Summary: This album contains images with objects such as car, chair, person, boat, truck.
#
# Album ID: 64
# Generated Summary: This album contains images with objects such as bench, person, backpack, handbag, car.
#
# Album ID: 65
# Generated Summary: This album contains images with objects such as clock, bird, bench, train, person.
#
# Album ID: 66
# Generated Summary: This album contains images with objects such as clock, chair, person, car, handbag.
#
# Album ID: 67
# Generated Summary: This album contains images with objects such as chair, potted plant, bottle, laptop, couch.
#
# Album ID: 68
# Generated Summary: This album contains images with objects such as person, potted plant, toilet, vase, sports ball.
#
# Album ID: 69
# Generated Summary: This album contains images with objects such as person, sink, bowl, potted plant, bird.
#
# Album ID: 70
# Generated Summary: This album contains images with objects such as car, person, potted plant, bicycle, traffic light.
#
# Album ID: 71
# Generated Summary: This album contains images with objects such as chair, person, umbrella, potted plant, handbag.
#
# Album ID: 72
# Generated Summary: This album contains images with objects such as person, potted plant, car, handbag, dog.
#
# Album ID: 73
# Generated Summary: This album contains images with objects such as person, potted plant, traffic light, handbag, elephant.
#
# Album ID: 74
# Generated Summary: This album contains images with objects such as person, backpack, clock, truck, bird.
#
# Album ID: 75
# Generated Summary: This album contains images with objects such as horse, person, dog, car, bird.
#
# Album ID: 76
# Generated Summary: This album contains images with objects such as person, clock, handbag, umbrella, backpack.
#
# Album ID: 77
# Generated Summary: This album contains images with objects such as clock, person, handbag, backpack, potted plant.
#
# Album ID: 78
# Generated Summary: This album contains images with objects such as sheep, cow, backpack, person, handbag.
